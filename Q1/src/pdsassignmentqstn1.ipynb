# %%
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
os.chdir('/content/drive/MyDrive/pdsassignment1/source/pdsassignmentqstn1')
os.getcwd()
# Out:
# '/content/drive/MyDrive/pdsassignment1/source/pdsassignmentqstn1'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('rawdata/raw.csv')
data.head()
# Out:
#   Height (Inches) Weight (Pounds)  Age Grip strength Frailty
# 0           65.8             112   30            30       N
# 1           71.5             136   19            31       N
# 2           69.4             153   45            29       N
# 3           68.2             142   22            28       Y
# 4           67.8             144   29            24       Y

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Height (Inches)  10 non-null     object
#  1   Weight (Pounds)  10 non-null     object
#  2   Age              10 non-null     object
#  3   Grip strength    10 non-null     object
#  4   Frailty          10 non-null     object
# dtypes: object(5)
# memory usage: 528.0+ bytes

# %%
processed=data.copy()

# %%
for i in processed.columns[:-1]:
  processed[i]=processed[i].astype('float')
processed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Height (Inches)  10 non-null     float64
#  1   Weight (Pounds)  10 non-null     float64
#  2   Age              10 non-null     float64
#  3   Grip strength    10 non-null     float64
#  4   Frailty          10 non-null     object
# dtypes: float64(4), object(1)
# memory usage: 528.0+ bytes

# %%
processed.to_csv('/content/drive/MyDrive/pdsassignment1/source/pdsassignmentqstn1/processeddata/processed.csv',index=False)

# %%
pdata = pd.read_csv('/content/drive/MyDrive/PDS_Assignment-1/Part-1/processed_data/processed.csv')

# %%
from matplotlib import markers
plt.figure(figsize=(25,5))
plt.subplot(1,3,1)
plt.plot(data['Age'],data['Height (Inches)'],'r',marker='^',ms=10,label='Height')
plt.title('Age vs Height')
plt.xlabel('Age')
plt.ylabel('Height')
plt.legend()
plt.subplot(1,3,2)
plt.plot(data['Age'],data['Weight (Pounds)'],'g',marker='o',ms=10,label='Weight')
plt.title('Age vs weight')
plt.xlabel('Age')
plt.ylabel('Weight')
plt.legend()
plt.subplot(1,3,3)
plt.plot(data['Age'],data['Grip strength'],marker='v',ms=10,label='Grip strength')
plt.title('Age vs Grip strength')
plt.xlabel('Age')
plt.ylabel('Grip strength')
plt.legend()
plt.show()
